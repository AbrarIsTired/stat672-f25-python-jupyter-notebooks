# %% [markdown]
# Abrar Nomani
# 25F-STAT672-019
# Assignment #1
#
# This assignment accompanies module 1. You need to turn in your Python script file. Save all your code into one file with name:
#
# <your first name>-<your last name>-M1.ipynb, and submit. Include your explanations and text answers as comments.
#
# Q1. Coding practice.
#
# -Follow the instructions in the video to install Anaconda in your computer. Download the most up to date version.
#
# -Use your ‘File Explorer’ to create a subfolder ‘STAT672’ under ‘Documents’, and this is where you’ll save your Jupyter scripts.
#
# -After the Anaconda is installed, launch Jupyter notebook, and study the directory.Click through to get in the subfolder you just created.
#
# -Launch Python and write you first Python program to print out “hello Stat-667! My name is <your name>”.

# %%
print("Hello Stat-667! My name is Abrar")
# Out:
# Hello Stat-667! My name is Abrar

# %% [markdown]
# Q2. Coding exercise on variables.
#
# • Assign 3.0 to variable a, print out the type of a. Use a built-in function to convert the type
# of a to integer, print out the type of a again.
#
# • Assign string “great” to variable s1, string “course” to variable s2, and string ‘ha’ to
# variable s3. use string concatenation and repetition to form a string “great course,
# hahaha” and assign it to variable s4.

# %%
a = 3.0
print(type(a))

a = int(a)
print(type(a))

s1 = "great"
s2  = "course"
s3 = "ha"
s4 = s1 + " " + s2 + " " + s3 + s3 + s3
print(s4)
# Out:
# <class 'float'>
# <class 'int'>
# great course hahaha

# %% [markdown]
# Q3. Below is an example of getting user input to calculate the area of a circle.
#
# radius = int(input("Enter the radius:"))
#
# area = (radius * radius) * 3.1415
#
# print("The area of a circle with radius", radius, "is:", area)
#
# Modify it to get user intput to calculate the circumference of a circle. Then, use it to calculate
# the C of a circle with radius of 10.

# %%
radius = int(input("Enter the radius:"))
area = (radius * radius) * 3.1415
circumference = (2 * 3.14 * radius)
print("The circumference is: ", circumference, " Using the Radius:", radius)
print("The area of a circle with radius", radius, "is:", area)
# Out:
# The circumference is:  62.800000000000004  Using the Radius: 10
# The area of a circle with radius 10 is: 314.15000000000003
